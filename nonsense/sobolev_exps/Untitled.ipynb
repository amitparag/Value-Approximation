# %%
import numpy as np
import numpy as np
import crocoddyl
import torch
from tqdm import tqdm
from utils import Solver
from utils import Datagen
from utils import TerminalModelUnicycle
from network import ValueNet
import time
torch.set_default_dtype(torch.double)

import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

net0 = torch.load('./networks/net0.pth')
net5 = torch.load('./networks/net5.pth')
net8 = torch.load('./networks/net8.pth')

net9 = torch.load('./networks/net9.pth')
net11 = torch.load('./networks/net11.pth')

net10 = torch.load('./networks/net10.pth')
net20 = torch.load('./networks/net20.pth')

net42 = torch.load('./networks/net43.pth')
net43 = torch.load('./networks/net43.pth')
net44 = torch.load('./networks/net44.pth')
net45 = torch.load('./networks/net45.pth')

# %%
x1 = np.random.uniform(-1.5, 1.5)
x2 = np.random.uniform(-1.5, 1.5)
x3 = np.random.uniform(-.75, .75)
x0 = np.array([x1, x2, x3])
x0 = np.array([-1.14, -1.75, -.3546])

terminal_ = TerminalModelUnicycle(neural_net=net45)
ddp, log, = Solver()._solveProblem(initial_config=x0,logger=True)
ddp2, log2 = Solver(terminal_model=terminal_)._solveProblem(initial_config=x0, logger=True)
log = log.stops[1:]
log2 = log2.stops[1:]
print("\n Stopping Criteria")
print(f"\n   Crocoddyl = {log[1:5]}")
print(f"\n   Terminal Croc = {log2[1:5]}")

ddp.cost

ddp2.cost

net10(torch.Tensor(x0))
# Out:
#  Stopping Criteria
#
#    Crocoddyl = [59.77091206593007, 51.63161957892736, 12.103021528381927, 8.223841519943262]
#
#    Terminal Croc = [57.69063765766376, 48.77631414949093, 11.555688022291287, 7.8355150433997975]
# tensor([23.9532], grad_fn=<AddBackward0>)

# %%
plt.figure(figsize=(12, 10))
plt.plot(log,'--o', label ='Crocoddyl')
plt.plot(log2, "--o", label = "Sobolev Trained Net in Crocoddyl")
plt.legend()
plt.title("Sobolev Network", fontsize =15)
plt.ylabel("Stopping Criteria", fontsize =15)
plt.xlabel("ddp.iters", fontsize =15)
plt.savefig("sobolev.png")

# %%
import numpy as np

# %%
a = [-0.97139655, -1.30424489 , 0.5899353 ]

# %%
a**2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-9d14bf4ad06f> in <module>
# ----> 1 a**2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'
