# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data_generator import Datagen
from feedforward_network import FeedForwardNet
from residual_network import ResidualNet
from terminal_unicycle import FeedforwardUnicycle, ResidualUnicycle
from ddp_solver import solve_problem
import numpy as np
import torch
import matplotlib.pyplot as plt
from utils import plot_trajectories

# %%
fnet1 = torch.load('./Fnet/net1.pth')
fnet5 = torch.load('./Fnet/net5.pth')
fnet10 = torch.load('./Fnet/net10.pth')
fnet17 = torch.load('./Fnet/net17.pth')
fnet30 = torch.load('./Fnet/net30.pth')
fnet50 = torch.load('./Fnet/net50.pth')


rnet1 = torch.load('./Rnet/net1.pth')
rnet5 = torch.load('./Rnet/net5.pth')
rnet10 = torch.load('./Rnet/net10.pth')
rnet17 = torch.load('./Rnet/net17.pth')
rnet30 = torch.load('./Rnet/net30.pth')
rnet50 = torch.load('./Rnet/net50.pth')

# %%
x_f1, c_f1 = Datagen.data(ntrajectories=40,terminal_model=FeedforwardUnicycle(fnet1))
x_f5, c_f5 = Datagen.data(ntrajectories=40,terminal_model=FeedforwardUnicycle(fnet5))
x_f10, c_f10 = Datagen.data(ntrajectories=40,terminal_model=FeedforwardUnicycle(fnet10))
x_f17, c_f17 = Datagen.data(ntrajectories=40,terminal_model=FeedforwardUnicycle(fnet17))
x_f30, c_f30 = Datagen.data(ntrajectories=40,terminal_model=FeedforwardUnicycle(fnet30))
x_f50, c_f50 = Datagen.data(ntrajectories=40,terminal_model=FeedforwardUnicycle(fnet50))
# Out:
# Sampling 40 [x, y, z] from:
#
#   x = [-2.1, 2.1]
#
#   y = [-2.1, 2.1]
#
#   z = [-6.283185307179586, 6.283185307179586]
#
# Sampling 40 [x, y, z] from:
#
#   x = [-2.1, 2.1]
#
#   y = [-2.1, 2.1]
#
#   z = [-6.283185307179586, 6.283185307179586]
#
# Sampling 40 [x, y, z] from:
#
#   x = [-2.1, 2.1]
#
#   y = [-2.1, 2.1]
#
#   z = [-6.283185307179586, 6.283185307179586]
#
# Sampling 40 [x, y, z] from:
#
#   x = [-2.1, 2.1]
#
#   y = [-2.1, 2.1]
#
#   z = [-6.283185307179586, 6.283185307179586]
#
# Sampling 40 [x, y, z] from:
#
#   x = [-2.1, 2.1]
#
#   y = [-2.1, 2.1]
#
#   z = [-6.283185307179586, 6.283185307179586]
#
# Sampling 40 [x, y, z] from:
#
#   x = [-2.1, 2.1]
#
#   y = [-2.1, 2.1]
#
#   z = [-6.283185307179586, 6.283185307179586]

# %%
x_r1, c_r1 = Datagen.data(ntrajectories=40,terminal_model=ResidualUnicycle(rnet1))
x_r5, c_r5 = Datagen.data(ntrajectories=40,terminal_model=ResidualUnicycle(rnet5))
x_r10, c_r10 = Datagen.data(ntrajectories=40,terminal_model=ResidualUnicycle(rnet10))
x_r17, c_r17 = Datagen.data(ntrajectories=40,terminal_model=ResidualUnicycle(rnet17))
x_r30, c_r30 = Datagen.data(ntrajectories=40,terminal_model=ResidualUnicycle(rnet30))
x_r50, c_r50 = Datagen.data(ntrajectories=40,terminal_model=ResidualUnicycle(rnet50))
# Out:
# Sampling 40 [x, y, z] from:
#
#   x = [-2.1, 2.1]
#
#   y = [-2.1, 2.1]
#
#   z = [-6.283185307179586, 6.283185307179586]
#
# Sampling 40 [x, y, z] from:
#
#   x = [-2.1, 2.1]
#
#   y = [-2.1, 2.1]
#
#   z = [-6.283185307179586, 6.283185307179586]
#
# Sampling 40 [x, y, z] from:
#
#   x = [-2.1, 2.1]
#
#   y = [-2.1, 2.1]
#
#   z = [-6.283185307179586, 6.283185307179586]
#
# Sampling 40 [x, y, z] from:
#
#   x = [-2.1, 2.1]
#
#   y = [-2.1, 2.1]
#
#   z = [-6.283185307179586, 6.283185307179586]
#
# Sampling 40 [x, y, z] from:
#
#   x = [-2.1, 2.1]
#
#   y = [-2.1, 2.1]
#
#   z = [-6.283185307179586, 6.283185307179586]
#
# Sampling 40 [x, y, z] from:
#
#   x = [-2.1, 2.1]
#
#   y = [-2.1, 2.1]
#
#   z = [-6.283185307179586, 6.283185307179586]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-421b0b70e7db> in <module>
# ...

# %%
x_rr1, c_r1 = Datagen.data(ntrajectories=40,terminal_model=ResidualUnicycle(rnet1, use_gauss_approx=True))
x_rr5, c_r5 = Datagen.data(ntrajectories=40,terminal_model=ResidualUnicycle(rnet5, use_gauss_approx=True))
x_rr10, c_r10 = Datagen.data(ntrajectories=40,terminal_model=ResidualUnicycle(rnet10, use_gauss_approx=True))
x_rr17, c_r17 = Datagen.data(ntrajectories=40,terminal_model=ResidualUnicycle(rnet17, use_gauss_approx=True))
x_rr30, c_r30 = Datagen.data(ntrajectories=40,terminal_model=ResidualUnicycle(rnet30, use_gauss_approx=True))
x_rr50, c_r50 = Datagen.data(ntrajectories=40,terminal_model=ResidualUnicycle(rnet50, use_gauss_approx=True))

# %%
# Make the figure:

fig, axs = plt.subplots(3, 2, figsize=(18, 20), sharex=True, sharey ='row')
fig.subplots_adjust(left=0.02, bottom=0.2, right=0.95, top=0.94, wspace=0.25)

# Plot prediction, cost
im1 = axs[0, 0].scatter(x = x_f1[:,0], y = x_f1[:,1], c= c_f1)
fig.colorbar(im1, ax=axs[0, 0])


im2 = axs[0, 1].scatter(x = x_f5[:,0], y = x_f5[:,1], c= c_f5)
fig.colorbar(im2, ax=axs[0, 1])



im3 = axs[1, 0].scatter(x = x_f10[:,0], y = x_f10[:,1], c= c_f10)
fig.colorbar(im3, ax=axs[1, 0])

im4 = axs[1, 1].scatter(x = x_f17[:,0], y = x_f17[:,1], c= c_f17)
fig.colorbar(im4, ax=axs[1, 1])


im5 = axs[2, 0].scatter(x = x_f30[:,0], y = x_f30[:,1], c= c_f30)
fig.colorbar(im5, ax=axs[2, 0])

im6 = axs[2, 1].scatter(x = x_f50[:,0], y = x_f50[:,1], c= c_f50)
fig.colorbar(im6, ax=axs[2, 1])
